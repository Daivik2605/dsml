# %%
# Import Pandas Library
import pandas as pd

# %%
# Read the dataset
df = pd.read_csv('C:\\Users\\daivi\\Desktop\\AML 1114 - Data science and machine learning\\Code and Datasets\\WEEK1-2\\2_customers.csv')

# %%
df.head()
# Out:
#      id       cust_name  num_products province  len_relationship  \
# 0  1001  Johnny Awesome             3       ON                 1
# 1  1002      Bob Marley             4       ON                 1
# 2  1004    Taylor Swift             2       AB                 2
# 3  1101      James Dean             3       BC                 3
# 4  1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df.shape
# Out:
# (13, 6)

# %% [markdown]
# - We have 13 Records
# - We have 6 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                13 non-null     int64
#  1   cust_name         13 non-null     object
#  2   num_products      13 non-null     int64
#  3   province          13 non-null     object
#  4   len_relationship  13 non-null     int64
#  5   cust_category     13 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 756.0+ bytes

# %%
# Lets view one column
df['id']
# Out:
# 0     1001
# 1     1002
# 2     1004
# 3     1101
# 4     1006
# 5     1014
# 6     1254
# 7     1285
# 8     1354
# 9     1005
# 10    1008
# 11    1585
# 12    1475
# Name: id, dtype: int64

# %%
df['province']
# Out:
# 0     ON
# 1     ON
# 2     AB
# 3     BC
# 4     ON
# 5     AB
# 6     AB
# 7     ON
# 8     BC
# 9     BC
# 10    MB
# 11    AB
# 12    ON
# Name: province, dtype: object

# %%
# Lets view 2 columns as a dataframe
df[['id', 'province']]
# Out:
#       id province
# 0   1001       ON
# 1   1002       ON
# 2   1004       AB
# 3   1101       BC
# 4   1006       ON
# 5   1014       AB
# 6   1254       AB
# 7   1285       ON
# 8   1354       BC
# 9   1005       BC
# 10  1008       MB
# 11  1585       AB
# 12  1475       ON

# %%
df.head()
# Out:
#      id       cust_name  num_products province  len_relationship  \
# 0  1001  Johnny Awesome             3       ON                 1
# 1  1002      Bob Marley             4       ON                 1
# 2  1004    Taylor Swift             2       AB                 2
# 3  1101      James Dean             3       BC                 3
# 4  1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
#Rename column
# 'id' -> 'cust_id'

# %%
df.rename(columns = {'id': 'cust_id'}, inplace = True)

# %%
df.head()
# Out:
#    cust_id       cust_name  num_products province  len_relationship  \
# 0     1001  Johnny Awesome             3       ON                 1
# 1     1002      Bob Marley             4       ON                 1
# 2     1004    Taylor Swift             2       AB                 2
# 3     1101      James Dean             3       BC                 3
# 4     1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df2 = df.set_index('cust_id')
# set_index sets cust_id as the index

# %%
df.head()
# Out:
#    cust_id       cust_name  num_products province  len_relationship  \
# 0     1001  Johnny Awesome             3       ON                 1
# 1     1002      Bob Marley             4       ON                 1
# 2     1004    Taylor Swift             2       AB                 2
# 3     1101      James Dean             3       BC                 3
# 4     1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2.axes
# axes gives the rows and columns, sometimes axes can be a parameter you will have to set
# if axis = 0 -> refers to rows
# axis =1 -> refers to columns
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='cust_id'),
#  Index(['cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %% [markdown]
# ### Arrange or organize the dataset(df2) such that the column names appear in ascending order

# %%
# sort_index
df2.sort_index(axis = 1, ascending = True)
# Out:
#             cust_category           cust_name  len_relationship  num_products  \
# cust_id
# 1001               wealth      Johnny Awesome                 1             3
# 1002     personal_banking          Bob Marley                 1             4
# 1004                  hnw        Taylor Swift                 2             2
# 1101               wealth          James Dean                 3             3
# 1006                  hnw       Stephen Smith                 4             5
# 1014     personal_banking       Delilah Avery                 3             2
# 1254                  hnw        Johnson Cory                 4             1
# 1285               wealth          Maria Alva                 2             5
# 1354     personal_banking        Jessica Fast                 5             4
# 1005     personal_banking  Mariah Anita Smith                 3             2
# 1008                  hnw      Robert Optimus                10             3
# ...

# %% [markdown]
# ### Sort the DF such that the person with the longest length of relationship appears first

# %%
# sort_values
df2.sort_values(by = 'len_relationship', ascending=False)
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1008         Robert Optimus             3       MB                10
# 1354           Jessica Fast             4       BC                 5
# 1475      Stephanie Element             2       ON                 5
# 1006          Stephen Smith             5       ON                 4
# 1254           Johnson Cory             1       AB                 4
# 1101             James Dean             3       BC                 3
# 1014          Delilah Avery             2       AB                 3
# 1005     Mariah Anita Smith             2       BC                 3
# 1004           Taylor Swift             2       AB                 2
# 1285             Maria Alva             5       ON                 2
# 1585           Steven Prime             5       AB                 2
# 1001         Johnny Awesome             3       ON                 1
# ...

# %% [markdown]
# ### Access all the information of the customer 'Bob Marley'

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2[df2['cust_name'] == 'Bob Marley']
# Out:
#           cust_name  num_products province  len_relationship     cust_category
# cust_id
# 1002     Bob Marley             4       ON                 1  personal_banking

# %%
# Use Loc
df2.loc[1002]
# Out:
# cust_name                 Bob Marley
# num_products                       4
# province                          ON
# len_relationship                   1
# cust_category       personal_banking
# Name: 1002, dtype: object

# %%
# Use iloc
df2.iloc[1]
# Out:
# cust_name                 Bob Marley
# num_products                       4
# province                          ON
# len_relationship                   1
# cust_category       personal_banking
# Name: 1002, dtype: object

# %% [markdown]
# - loc: label based access
# - iloc: index based access

# %% [markdown]
# ### Access all the information of the customer FROM 'Bob Marley' TO 'Stephen Smith'

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
# Using loc
df2.loc[1001: 1006]
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
# Using iloc
df2.iloc[0:5]
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %% [markdown]
# ### Access all the info FROM Bob Marley to Stephen Smith

# %%
df2.loc[1002:1006]
# Out:
#              cust_name  num_products province  len_relationship  \
# cust_id
# 1002        Bob Marley             4       ON                 1
# 1004      Taylor Swift             2       AB                 2
# 1101        James Dean             3       BC                 3
# 1006     Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %% [markdown]
# ### Access only the cust_name and province from Bob Marley to Stephen Smith

# %%
df2.loc[1002:1006, ['cust_name', 'province']]
# Out:
#              cust_name province
# cust_id
# 1002        Bob Marley       ON
# 1004      Taylor Swift       AB
# 1101        James Dean       BC
# 1006     Stephen Smith       ON

# %%
df2.iloc[1: 5, [0, 2]]
# Out:
#              cust_name province
# cust_id
# 1002        Bob Marley       ON
# 1004      Taylor Swift       AB
# 1101        James Dean       BC
# 1006     Stephen Smith       ON

# %% [markdown]
# ### Who has the longest length of relationship with the bank, get the cust name

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2['len_relationship'].max()
# Out:
# 10

# %%
df2[df2['len_relationship'] == df2['len_relationship'].max()]
# Out:
#               cust_name  num_products province  len_relationship cust_category
# cust_id
# 1008     Robert Optimus             3       MB                10           hnw

# %%
df2[df2['len_relationship'] == df2['len_relationship'].max()]['cust_name']
# Out:
# cust_id
# 1008    Robert Optimus
# Name: cust_name, dtype: object

# %% [markdown]
# ### Which users belong to Alberta

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2[df2['province'] == 'AB']
# Out:
#              cust_name  num_products province  len_relationship  \
# cust_id
# 1004      Taylor Swift             2       AB                 2
# 1014     Delilah Avery             2       AB                 3
# 1254      Johnson Cory             1       AB                 4
# 1585      Steven Prime             5       AB                 2
#
#             cust_category
# cust_id
# 1004                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1585               wealth

# %%
df2[df2['province'] == 'AB']['cust_name']
# Out:
# cust_id
# 1004     Taylor Swift
# 1014    Delilah Avery
# 1254     Johnson Cory
# 1585     Steven Prime
# Name: cust_name, dtype: object

# %% [markdown]
# ### Display the users belonging to either Ontario or Bitish Columbia

# %%
df2[(df2['province'] == 'ON') | (df2['province'] == 'BC')] ['cust_name']
# Out:
# cust_id
# 1001        Johnny Awesome
# 1002            Bob Marley
# 1101            James Dean
# 1006         Stephen Smith
# 1285            Maria Alva
# 1354          Jessica Fast
# 1005    Mariah Anita Smith
# 1475     Stephanie Element
# Name: cust_name, dtype: object

# %%
df2[(df2['province'] == 'ON') | (df2['province'] == 'BC')]
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %% [markdown]
# ### Customers with atleast 4 products

# %%
df2[df2['num_products'] >= 4] ['cust_name']
# Out:
# cust_id
# 1002       Bob Marley
# 1006    Stephen Smith
# 1285       Maria Alva
# 1354     Jessica Fast
# 1585     Steven Prime
# Name: cust_name, dtype: object

# %% [markdown]
# ### customers belonging to Ontario, Alberta, British Columbia:

# %%
df2[(df2['province'] == 'ON') | (df2['province'] == 'AB') | (df2['province'] == 'BC')]
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             cust_category
# cust_id
# ...

# %%
df2[(df2['province'] == 'ON') | (df2['province'] == 'AB') | (df2['province'] == 'BC')] [['cust_name', 'province']]
# Out:
#                   cust_name province
# cust_id
# 1001         Johnny Awesome       ON
# 1002             Bob Marley       ON
# 1004           Taylor Swift       AB
# 1101             James Dean       BC
# 1006          Stephen Smith       ON
# 1014          Delilah Avery       AB
# 1254           Johnson Cory       AB
# 1285             Maria Alva       ON
# 1354           Jessica Fast       BC
# 1005     Mariah Anita Smith       BC
# 1585           Steven Prime       AB
# 1475      Stephanie Element       ON

# %% [markdown]
# ### What is the average length of relationship that customers have with the bank

# %%
df2['len_relationship'].mean()
# Out:
# 3.4615384615384617

# %%
round(df2['len_relationship'].mean())
# Out:
# 3

# %% [markdown]
# ### Which province occurs the most number of times

# %%
df2['province'].mode()
# Out:
# 0    ON
# Name: province, dtype: object

# %%
df2['province'].value_counts()
# Out:
# province
# ON    5
# AB    4
# BC    3
# MB    1
# Name: count, dtype: int64

# %% [markdown]
# ### Which are the banking categories present , and how many customers are present per category

# %%
df2.head(2)
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking

# %%
df2['cust_category'].value_counts()
# Out:
# cust_category
# personal_banking    5
# wealth              4
# hnw                 4
# Name: count, dtype: int64

# %%
df2.groupby('cust_category') ['cust_name'].value_counts()
# Out:
# cust_category     cust_name
# hnw               Johnson Cory          1
#                   Robert Optimus        1
#                   Stephen Smith         1
#                   Taylor Swift          1
# personal_banking  Bob Marley            1
#                   Delilah Avery         1
#                   Jessica Fast          1
#                   Mariah Anita Smith    1
#                   Stephanie Element     1
# wealth            James Dean            1
#                   Johnny Awesome        1
#                   Maria Alva            1
#                   Steven Prime          1
# Name: count, dtype: int64

# %% [markdown]
# ### Which are the banking categories present , and how many average products are purchased by customers per category

# %%
df2.groupby('cust_category') ['num_products'].mean()
# Out:
# cust_category
# hnw                 2.75
# personal_banking    2.80
# wealth              4.00
# Name: num_products, dtype: float64

# %% [markdown]
# ### Finding the Frequency of all the provinces

# %%
df2.groupby('province') ['cust_name'].value_counts()
# Out:
# province  cust_name
# AB        Delilah Avery         1
#           Johnson Cory          1
#           Steven Prime          1
#           Taylor Swift          1
# BC        James Dean            1
#           Jessica Fast          1
#           Mariah Anita Smith    1
# MB        Robert Optimus        1
# ON        Bob Marley            1
#           Johnny Awesome        1
#           Maria Alva            1
#           Stephanie Element     1
#           Stephen Smith         1
# Name: count, dtype: int64

# %%
df2['province'].value_counts()
# Out:
# province
# ON    5
# AB    4
# BC    3
# MB    1
# Name: count, dtype: int64
